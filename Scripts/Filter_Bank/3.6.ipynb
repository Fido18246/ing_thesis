# %% [markdown]
# # Morfologické filtry

# %%
import matplotlib.pyplot as plt
import numpy as np
import cv2

# %%
DATA_PATH = f'../../Results/Resizing_Images/Images_ALL/2023_12_14_image_000.png'

img = cv2.imread(DATA_PATH)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

r, g, b = cv2.split(img)
kernel = np.ones((5, 5), np.uint8)

# %%
def plot_images(img_ori,img_fil, title):

    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(16,9))

    ax1.title.set_text('Original image')
    ax1.imshow(img_ori)

    ax2.title.set_text(f'{title}')
    ax2.imshow(img_fil)

    plt.show()

# %%
erosion_r = cv2.erode(r, kernel, iterations=1)
erosion_g = cv2.erode(g, kernel, iterations=1)
erosion_b = cv2.erode(b, kernel, iterations=1)

eroded_image = cv2.merge([erosion_r, erosion_g, erosion_b])

plot_images(img, eroded_image, 'erode')

# %%
dilation_r = cv2.dilate(r, kernel, iterations=1)
dilation_g = cv2.dilate(g, kernel, iterations=1)
dilation_b = cv2.dilate(b, kernel, iterations=1)

eroded_image = cv2.merge([dilation_r, dilation_g, dilation_b])

plot_images(img, eroded_image, 'dilate')
