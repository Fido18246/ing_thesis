# %%
import matplotlib.pyplot as plt

import pandas as pd
import numpy as np

# %%
n_clusters = 1584

INPUT_PATH = f'../../../Results/Workflow_Testing/PCA_effect_exploring_PoC_C_{n_clusters}/'

df_LinearSVC = pd.read_csv(f'{INPUT_PATH}LinearSVC_120.csv')
df_SVC = pd.read_csv(f'{INPUT_PATH}SVC_120.csv')
df_RF = pd.read_csv(f'{INPUT_PATH}RF_110.csv')

INPUT_PATH_CLUSTERED = f'../../../Results/Workflow_Testing/Selection_effect_exploring_PoC_C_{n_clusters}/'

df_LinearSVC_S = pd.read_csv(f'{INPUT_PATH_CLUSTERED}LinearSVC.csv', index_col=0)
df_SVC_S = pd.read_csv(f'{INPUT_PATH_CLUSTERED}SVC.csv', index_col=0)
df_RF_S = pd.read_csv(f'{INPUT_PATH_CLUSTERED}RF.csv', index_col=0)

LinearSVC_row = df_LinearSVC_S.loc[120]
SVC_row = df_SVC_S.loc[120]
RF_row = df_RF_S.loc[110]

# %%
col_names = list(['Accuracy', 'Jaccard_index', 'Dice_coefficient'])
x = list(df_LinearSVC.index)

fig, axes = plt.subplots(nrows=1, ncols=len(col_names), figsize=(15, 3))

for i, column in enumerate(col_names):

    axes[i].plot(x, df_LinearSVC[f'{column}_mean'], color='green', linestyle=':')
    axes[i].errorbar(x, df_LinearSVC[f'{column}_mean'], yerr=df_LinearSVC[f'{column}_std'], fmt='o', color='green', label=f'LinearSVC')

    axes[i].plot(x, df_SVC[f'{column}_mean'], color='red', linestyle=':')
    axes[i].errorbar(x, df_SVC[f'{column}_mean'], yerr=df_SVC[f'{column}_std'], fmt='o', color='red', label=f'SVC')

    axes[i].plot(x, df_RF[f'{column}_mean'], color='blue', linestyle=':')
    axes[i].errorbar(x, df_RF[f'{column}_mean'], yerr=df_RF[f'{column}_std'], fmt='o', color='blue', label=f'RF')

    axes[i].set_xticks(list(df_LinearSVC.index))
    axes[i].set_xticklabels(list(df_LinearSVC['PCA_target_dimension'].values))
    axes[i].set_xlabel('Počet komponent')
    axes[i].set_ylabel(f'{column}')
    axes[i].tick_params(axis='x', rotation=90)

    axes[i].axhline(y=LinearSVC_row[f'{column}_mean'], color='g', linestyle='--', label=f'LinearSVC bez PCA')
    axes[i].axhline(y=SVC_row[f'{column}_mean'], color='r', linestyle='--', label=f'SVC bez PCA')
    axes[i].axhline(y=RF_row[f'{column}_mean'], color='b', linestyle='--', label=f'RF bez PCA')

plt.legend(loc='upper left', bbox_to_anchor=(1, 1))
plt.tight_layout(pad=1.0)
plt.savefig(f'{INPUT_PATH}metrics.png')
plt.show()

# %%
plt.figure(figsize=(10,3))

# LinearSVC
plt.plot(df_LinearSVC[f'Dice_coefficient_mean'], color='green', linestyle=':')
plt.scatter(list(df_LinearSVC.index), df_LinearSVC[f'Dice_coefficient_mean'], marker='o', color='green', label='LinearSVC')

plt.axhline(y=LinearSVC_row[f'Dice_coefficient_mean'], color='g', linestyle='--', label=f'LinearSVC bez PCA')

# SVC
plt.plot(df_SVC[f'Dice_coefficient_mean'], color='red', linestyle=':')
plt.scatter(list(df_SVC.index), df_SVC[f'Dice_coefficient_mean'], marker='o', color='red', label='SVC')

plt.axhline(y=SVC_row[f'Dice_coefficient_mean'], color='r', linestyle='--', label=f'SVC bez PCA')

# RF
plt.plot(df_RF[f'Dice_coefficient_mean'], color='blue', linestyle=':')
plt.scatter(list(df_RF.index), df_RF[f'Dice_coefficient_mean'], marker='o', color='blue', label='RF')

plt.axhline(y=RF_row[f'Dice_coefficient_mean'], color='b', linestyle='--', label=f'RF bez PCA')

# Settings
plt.title('Úspěšnost segmentace')
plt.xlabel('Počet komponent')
plt.ylabel('DSC')
plt.legend(loc='upper left', bbox_to_anchor=(1, 1))
plt.xticks(list(df_RF.index), labels=list(df_RF['PCA_target_dimension'].values))
plt.tick_params(axis='x', rotation=90)

plt.show()

# %%
max_LinearSVC = df_LinearSVC['Dice_coefficient_mean'].idxmax()
max_SVC = df_SVC['Dice_coefficient_mean'].idxmax()
max_RF = df_RF['Dice_coefficient_mean'].idxmax()

print(f"LinearSVC má maximální DSC: {df_LinearSVC.at[max_LinearSVC, 'Dice_coefficient_mean']:.3f} +- {df_LinearSVC.at[max_LinearSVC, 'Dice_coefficient_std']:.3f} a to pro {df_LinearSVC.at[max_LinearSVC, 'PCA_target_dimension']} komponent.")
print(f"SVC má maximální DSC: {df_SVC.at[max_SVC, 'Dice_coefficient_mean']:.3f} +- {df_SVC.at[max_SVC, 'Dice_coefficient_std']:.3f} a to pro {df_SVC.at[max_SVC, 'PCA_target_dimension']} komponent.")
print(f"RF má maximální DSC: {df_RF.at[max_RF, 'Dice_coefficient_mean']:.3f} +- {df_RF.at[max_RF, 'Dice_coefficient_std']:.3f} a to pro {df_RF.at[max_RF, 'PCA_target_dimension']} komponent.")
# Out:
# LinearSVC má maximální DSC: 0.854 +- 0.015 a to pro 11 komponent.
# SVC má maximální DSC: 0.878 +- 0.014 a to pro 10 komponent.
# RF má maximální DSC: 0.855 +- 0.013 a to pro 11 komponent.

# %%
plt.figure(figsize=(10,3))

# LinearSVC
plt.scatter(df_LinearSVC.index, np.log10(df_LinearSVC['Time']), color='green', label='LinearSVC')
plt.plot(df_LinearSVC.index, np.log10(df_LinearSVC['Time']), color='green', linestyle=':')

plt.axhline(y=np.log10(LinearSVC_row['Time']), color='g', linestyle='--', label='LinearSVC bez PCA')

# SVC
plt.scatter(df_SVC.index, np.log10(df_SVC['Time']), color='red', label='SVC')
plt.plot(df_SVC.index, np.log10(df_SVC['Time']), color='red', linestyle=':')

plt.axhline(y=np.log10(SVC_row['Time']), color='r', linestyle='--', label='SVC bez PCA')

# RF
plt.scatter(df_RF.index, np.log10(df_RF['Time']), color='blue', label='RF')
plt.plot(df_RF.index, np.log10(df_RF['Time']), color='blue', linestyle=':')

plt.axhline(y=np.log10(RF_row['Time']), color='b', linestyle='--', label='RF bez PCA')

# Settings
plt.title('Časová náročnost logaritmicky')
plt.xlabel('Počet komponent')
plt.ylabel('log10($Čas_{sec}$)')
plt.legend(loc='upper left', bbox_to_anchor=(1, 1))
plt.xticks(list(df_RF.index), labels=list(df_RF['PCA_target_dimension'].values))
plt.tick_params(axis='x', rotation=90)

plt.show()
